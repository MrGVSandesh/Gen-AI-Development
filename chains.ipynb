# %% [markdown]
# ## Simple Chain

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("gemini-2.5-flash-lite", model_provider="google_vertexai")

# %%
from langchain_core.prompts import PromptTemplate

template = """You are an experienced cook.

List the ingredients to cook the following food item {food}
"""

prompt_template = PromptTemplate.from_template(template=template)

# %%
# Create a chain 

chain = prompt_template | llm

# %%
# execute the chain

response = chain.invoke({"food": "pasta"})
print(response.content)
# Out:
# Ah, pasta! A beautiful canvas for so many delicious dishes. As an experienced cook, I know that "pasta" itself is a broad term, and the ingredients can vary wildly depending on the *type* of pasta dish you're aiming for.
#
# However, if you're asking for the absolute foundational ingredients to simply *cook pasta* as a base for *any* dish, here's what you'll need:
#
# **The Essentials for Cooking Pasta:**
#
# 1.  **Pasta:** This is the star, of course! The type is entirely up to you and your desired dish. Some common options include:
#     *   **Dried Pasta:** Spaghetti, penne, fusilli, farfalle, rigatoni, macaroni, lasagna sheets, etc. (usually made from durum wheat semolina and water)
#     *   **Fresh Pasta:** Egg pasta, spinach pasta, etc. (often includes eggs, flour, and sometimes water)
#
# 2.  **Water:** Plenty of it! This is crucial for properly cooking the pasta and preventing it from sticking. Think of it like boiling a large pot of soup.
#
# 3.  **Salt:** Absolutely non-negotiable for flavoring the pasta itself. It should be added to the boiling water, and generously so. Think of it as seasoning the pasta from the inside out. A good rule of thumb is about 1 to 2 tablespoons of salt per gallon of water.
#
# **Optional, but Highly Recommended for Better Flavor & Texture:**
#
# 4.  **A Big Pot:** While not an "ingredient" in the culinary sense, it's an essential piece of equipment that directly impacts the outcome. A large pot allows for plenty of water, preventing clumping.
#
# **What's *Not* an Ingredient for *Cooking* Pasta Itself:**
#
# It's important to distinguish between cooking the pasta and making a pasta *dish*. The ingredients below are for the *sauce* or *accompaniments*, not for the pasta itself:
#
# *   **Olive Oil/Butter:** While sometimes added to the *sauce*, adding oil to the boiling water is generally discouraged by most experienced cooks as it can prevent the sauce from clinging to the pasta later.
# *   **Garlic, Onions, Tomatoes, Meats, Vegetables, Herbs, Spices, Cheese:** These are all fantastic for building a sauce, but they are not part of the fundamental process of cooking the pasta itself.
#
# **In summary, to simply cook pasta to a perfectly al dente stage, you need:**
#
# *   **Pasta**
# *   **Water**
# *   **Salt**
#
# Once your pasta is cooked, you can then decide what delicious sauce or additions you'd like to toss it with! Happy cooking!

# %%
response = chain.invoke({"food": "biryani"})
print(response.content)
# Out:
# Alright, let's get cooking! Biryani is a dish that requires a good amount of ingredients to build those complex, layered flavors. As an experienced cook, I know that the quality of your ingredients, especially the aromatics and spices, will make a huge difference.
#
# Here's a comprehensive list of ingredients for a classic biryani. I'll break it down into categories to make it easier to shop and prepare. This list is for a *standard* biryani (often chicken or lamb), and you can adjust quantities based on how much you're making.
#
# ---
#
# **The Star of the Show (Your Protein):**
#
# *   **Meat/Poultry:**
#     *   **Chicken:** 1 kg (about 2.2 lbs), cut into medium pieces (bone-in adds more flavor)
#     *   **Lamb/Mutton:** 1 kg (about 2.2 lbs), cut into medium pieces (bone-in is preferred for biryani)
#     *   **Beef:** Less common for traditional biryani but can be used.
#     *   **Vegetables (for Veg Biryani):** Mixed vegetables like potatoes, carrots, peas, beans, cauliflower, paneer (Indian cottage cheese), mushrooms.
#
# **The Aromatic Base (Foundation of Flavor):**
#
# *   **Onions:** 3-4 large, thinly sliced (these will be fried until golden brown, a crucial step!)
# *   **Ginger:** 2-inch piece, grated or finely minced
# *   **Garlic:** 8-10 cloves, grated or finely minced
# *   **Green Chilies:** 3-5 (adjust to your spice preference), slit or finely chopped
#
# **The Rice (The Canvas):**
#
# *   **Basmati Rice:** 500g (about 2.5 cups). It's essential to use good quality, aged Basmati rice for its fragrance and long, slender grains.
#
# **The Spices (The Soul of Biryani):**
#
# *   **Whole Spices (for tempering and marination):**
#     *   **Bay Leaves:** 2-3
#     *   **Cinnamon Sticks:** 2-3 (about 1-inch pieces)
#     *   **Green Cardamom Pods:** 5-7
#     *   **Black Cardamom Pods:** 1-2 (these have a stronger, smoky flavor)
#     *   **Cloves:** 5-7
#     *   **Black Peppercorns:** 1 teaspoon
#     *   **Star Anise:** 1-2 (optional, but adds a lovely licorice note)
#
# *   **Ground Spices (for marination and layering):**
#     *   **Turmeric Powder:** 1 teaspoon
#     *   **Red Chili Powder:** 1-2 teaspoons (adjust to heat preference)
#     *   **Coriander Powder:** 2 tablespoons
#     *   **Cumin Powder:** 1 tablespoon
#     *   **Garam Masala:** 1-2 tablespoons (use a good quality, freshly made blend if possible)
#     *   **Biryani Masala (optional but highly recommended):** 1-2 tablespoons (store-bought or homemade, this is a pre-made blend that elevates biryani)
#
# **The Yogurt & Acid (For Tenderness and Tang):**
#
# *   **Yogurt (Dahi):** 1 cup (plain, full-fat yogurt is best for marination. Make sure it's not too sour.)
# *   **Lemon Juice:** 1-2 tablespoons (from about half a lemon)
#
# **The Fat (For Richness and Cooking):**
#
# *   **Ghee:** 4-6 tablespoons (clarified butter is traditional and adds unparalleled flavor)
# *   **Vegetable Oil:** 2-3 tablespoons (for frying onions, if not using all ghee)
#
# **The Fresh Herbs & Aromatics (For Brightness and Freshness):**
#
# *   **Fresh Mint Leaves:** A generous handful, chopped (essential for that signature biryani aroma)
# *   **Fresh Cilantro (Coriander Leaves):** A generous handful, chopped
#
# **The Dairy & Color (For the "Dum" and Visual Appeal):**
#
# *   **Milk:** 1/4 cup (warm)
# *   **Saffron Strands:** A pinch (soaked in the warm milk for about 15-20 minutes to release color and aroma)
# *   **Kewra Water (Pandanus Flower Extract) or Rose Water:** 1-2 teaspoons (optional, but adds a classic floral aroma)
#
# **For Layering and "Dum" Cooking:**
#
# *   **Salt:** To taste (for rice and meat marination)
# *   **Water:** Plenty for boiling rice and for the marination.
#
# ---
#
# **A Few Notes from My Kitchen:**
#
# *   **Quality of Spices:** Invest in good quality, fresh spices. Old spices lose their potency and aroma.
# *   **Onion Frying:** This is a critical step. Slowly fry your onions on medium-low heat until they are deeply golden brown and slightly crisp. This adds a sweet, caramelized depth to the biryani. Don't rush it!
# *   **Marination Time:** For best results, marinate your meat for at least 2-3 hours, or preferably overnight in the refrigerator.
# *   **Rice Par-boiling:** The rice is typically par-boiled, meaning it's cooked about 70-80% before layering. You want it to absorb the flavors from the meat and spices during the "dum" cooking.
# *   **"Dum" Cooking:** This is the slow-cooking process where the biryani is sealed and cooked on very low heat. This allows the flavors to meld beautifully.
#
# This list might seem long, but each ingredient plays a vital role in creating that magical biryani experience. Happy cooking! Let me know if you have any questions about specific steps or ingredients.

# %%
chain.stream({"food": "pasta"})
# Out:
# <generator object RunnableSequence.stream at 0x0000022A9C53D6C0>

# %%
chain.ainvoke({"food": "pasta"})
# Out:
# <coroutine object RunnableSequence.ainvoke at 0x0000022A9C580C10>

# %%
from langchain_google_vertexai import ChatVertexAI

model = ChatVertexAI(
    model_name="gemini-2.5-flash-lite",
    temperature=0.2,
    max_output_tokens=100,
)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16504\2303401210.py:3: DeprecationWarning: Use [`ChatGoogleGenerativeAI`][langchain_google_genai.ChatGoogleGenerativeAI] instead.
#   model = ChatVertexAI(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16504\2303401210.py:3: LangChainDeprecationWarning: The class `ChatVertexAI` was deprecated in LangChain 3.2.0 and will be removed in 4.0.0. An updated version of the class exists in the `langchain-google-genai package and should be used instead. To use it run `pip install -U `langchain-google-genai` and import as `from `langchain_google_genai import ChatGoogleGenerativeAI``.
#   model = ChatVertexAI(

# %%
model.invoke("what is capital of france ?")
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 6, 'candidates_token_count': 8, 'total_token_count': 14, 'prompt_tokens_details': [{'modality': 1, 'token_count': 6}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 8}], 'thoughts_token_count': 0, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -0.0027015134692192078, 'model_provider': 'google_vertexai', 'model_name': 'gemini-2.5-flash-lite'}, id='lc_run--019bedee-fbcc-74b2-93ca-f587e25e0091-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 8, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
from langchain.messages import SystemMessage, HumanMessage

response = model.invoke([
    SystemMessage("You are an expert cook"),
    HumanMessage("How to cook sambar ?")
])

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
response
# Out:
# AIMessage(content="Ah, sambar! A cornerstone of South Indian cuisine, a fragrant and flavorful lentil and vegetable stew that's both comforting and incredibly versatile. As an expert cook, I can tell you that while there are many regional variations, the core principles remain the same. Let's dive into how to make a delicious sambar.\n\nThis recipe will give you a classic, well-rounded sambar. Feel free to adjust vegetables and spices to your liking!\n\n## Classic Sambar Recipe\n\n", additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 11, 'candidates_token_count': 100, 'total_token_count': 111, 'prompt_tokens_details': [{'modality': 1, 'token_count': 11}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 100}], 'thoughts_token_count': 0, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'MAX_TOKENS', 'avg_logprobs': -0.18693052291870116, 'model_provider': 'google_vertexai', 'model_name': 'gemini-2.5-flash-lite'}, id='lc_run--019bedee-fdbc-7b51-883e-63f490679bfc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 100, 'total_tokens': 111, 'input_token_details': {'cache_read': 0}})

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Ah, sambar! A cornerstone of South Indian cuisine, a fragrant and flavorful lentil and vegetable stew that's both comforting and incredibly versatile. As an expert cook, I can tell you that while there are many regional variations, the core principles remain the same. Let's dive into how to make a delicious sambar.
#
# This recipe will give you a classic, well-rounded sambar. Feel free to adjust vegetables and spices to your liking!
#
# ## Classic Sambar Recipe

# %% [markdown]
# ## Document Loaders

# %%
## lets load a text document
from langchain_unstructured import UnstructuredLoader

txt_loader = UnstructuredLoader(file_path="../data/panchatantra.txt")

docs = txt_loader.load()
# Out:
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
for doc in docs:
    print(doc)
# Out:
# page_content='Long ago, in a vast and fertile kingdom bordered by rivers and forests, there stood a small village surrounded by mango trees and open fields. Near this village lived three close friends: a crow named Megha, a mouse named Hiranya, and a tortoise named Mantha. Though they were very different in size and nature, they trusted one another deeply and lived in harmony.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '59aaf355513ff4ab453e2437753d8776'}
# page_content='Megha, the crow, was sharp-eyed and quick-thinking. He spent his days flying across the land, observing the ways of humans and animals alike. Hiranya, the mouse, was small but extremely intelligent, with strong teeth and a quicker mind. Mantha, the tortoise, was slow in movement but wise and patient, known for thinking carefully before speaking or acting.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '3ba11f4babeb3bb5de8aa39fbaa1fb27'}
# page_content='Every evening, the three friends met near a quiet lake at the edge of the forest. They shared food, stories, and advice. Each respected the strengths of the others, and their friendship grew stronger with time.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '922dbb6e66f75188c5884d9bea49d587'}
# page_content='One summer, a terrible drought struck the land. The lake began to dry, crops failed, and food became scarce. Animals wandered far from their homes in search of water. The friends realized that difficult times were approaching.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '8a556b4a8705d6899da9db8f427d365a'}
# page_content='One evening, Megha flew in from afar looking worried. He said, “Friends, I have seen hunters setting traps near the forest. They are taking advantage of the drought. We must be careful.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'e335fbc08ecbba640713153fdc090da8'}
# page_content='Mantha nodded slowly. “Hard times test true friendship. We must remain united.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9580305586a97fd1e8c117aa37157448'}
# page_content='A few days later, a graceful deer named Chitranga came to the lake to drink water. He looked exhausted and frightened. Megha spoke kindly to him and invited him to join their group. Soon, Chitranga became part of their circle, and the four lived together peacefully.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '057986f861ec6036f69c58f5dcfeb53a'}
# page_content='One morning, while Chitranga went to graze, he unknowingly stepped into a hunter’s net hidden beneath dry grass. He struggled and cried out in fear. Hearing his cries, Megha flew up into the sky and quickly saw the danger.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '71915c3564cad1cbc929be72ae6b3602'}
# page_content='Megha rushed back to the lake and told Hiranya and Mantha what had happened. Hiranya said, “Do not worry. My teeth are sharp. If we act quickly, we can save him.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'ba8ea4a78b48fb4ca7819128f25492e5'}
# page_content='Mantha added calmly, “But we must be clever. The hunter may return at any moment.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '7a63d422adc0ac68adb4818dcdb096e8'}
# page_content='Megha flew back to Chitranga and whispered, “Do not panic. Pretend you are dead. Lie still.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'e577163663f3a661fd8ca6718fbb4e63'}
# page_content='Then Megha flew high and began circling the sky, cawing loudly. The noise caught the attention of the hunter, who soon arrived to check his net. When he saw the deer lying motionless, he thought, “The animal is already dead. I will return later to collect it.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9fc83788c21b238c250c6a14170b3e43'}
# page_content='As soon as the hunter left, Hiranya rushed in and began gnawing at the ropes of the net. His teeth worked swiftly, and soon the net was cut open.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'd3942b904350db1f91c3e77c29e02c16'}
# page_content='But before Chitranga could escape, Mantha, who had come slowly behind, was spotted by the hunter returning unexpectedly. The hunter caught the tortoise and tied him up.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f540e6b884a3d982f39df47f3966cd04'}
# page_content='Chitranga was filled with guilt and fear. “This happened because of me,” he cried.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '48aead6381bd846eabf54003d4edafdf'}
# page_content='Megha said firmly, “Now it is our turn to save Mantha. Listen carefully.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '63ce12c865e9547bc4eb4a0194629fd4'}
# page_content='They formed a plan. Chitranga ran toward the path, pretending to limp badly. Megha flew low, acting as if he were injured. Seeing this, the hunter thought, “If I follow them, I can catch even more animals.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'afe7ada7b42b30f4502db42f63147195'}
# page_content='The hunter dropped Mantha by the side of the path and ran after the deer and the crow. As soon as he was far away, Hiranya hurried to Mantha and gnawed through the ropes binding him.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f62ad51320dd2fcaac7876c5b012f1cc'}
# page_content='Once free, Mantha slowly crawled into the bushes. Meanwhile, Chitranga and Megha escaped into the forest. The hunter, realizing he had been tricked, returned angrily but found nothing.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f0a564f10e778a49c926d1a8ede40e0e'}
# page_content='That evening, the four friends reunited at the lake. They were tired but grateful. Mantha spoke gently, “Today we have learned that intelligence, patience, speed, and unity together can overcome even great danger.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a63d44df3ed3d5560849ee1acca75b9b'}
# page_content='Hiranya added, “Each of us alone would have failed, but together we succeeded.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'c026c58b6f31c4aa61870eb90dd14a59'}
# page_content='Chitranga bowed his head and said, “I will never forget this kindness. True friendship is life itself.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9622bfa80c35b1e37265ba3a1a8ee2d9'}
# page_content='Megha looked at the setting sun and said, “As long as we trust one another and act wisely, no enemy can defeat us.”' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'c56109fc54824755abcfb81bc7e7ad57'}
# page_content='From that day on, the friends lived cautiously but happily, always helping one another in times of trouble.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '8693e701193fb4258423e948ce1f3383'}
# page_content='Moral: True friendship, guided by wisdom and cooperation, can overcome even the greatest dangers.' metadata={'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a6f587f7d1109097f97b907db17ea0cd'}

# %%
# lets print content
for doc in docs:
    print(doc.page_content)
# Out:
# Long ago, in a vast and fertile kingdom bordered by rivers and forests, there stood a small village surrounded by mango trees and open fields. Near this village lived three close friends: a crow named Megha, a mouse named Hiranya, and a tortoise named Mantha. Though they were very different in size and nature, they trusted one another deeply and lived in harmony.
# Megha, the crow, was sharp-eyed and quick-thinking. He spent his days flying across the land, observing the ways of humans and animals alike. Hiranya, the mouse, was small but extremely intelligent, with strong teeth and a quicker mind. Mantha, the tortoise, was slow in movement but wise and patient, known for thinking carefully before speaking or acting.
# Every evening, the three friends met near a quiet lake at the edge of the forest. They shared food, stories, and advice. Each respected the strengths of the others, and their friendship grew stronger with time.
# One summer, a terrible drought struck the land. The lake began to dry, crops failed, and food became scarce. Animals wandered far from their homes in search of water. The friends realized that difficult times were approaching.
# One evening, Megha flew in from afar looking worried. He said, “Friends, I have seen hunters setting traps near the forest. They are taking advantage of the drought. We must be careful.”
# Mantha nodded slowly. “Hard times test true friendship. We must remain united.”
# A few days later, a graceful deer named Chitranga came to the lake to drink water. He looked exhausted and frightened. Megha spoke kindly to him and invited him to join their group. Soon, Chitranga became part of their circle, and the four lived together peacefully.
# One morning, while Chitranga went to graze, he unknowingly stepped into a hunter’s net hidden beneath dry grass. He struggled and cried out in fear. Hearing his cries, Megha flew up into the sky and quickly saw the danger.
# Megha rushed back to the lake and told Hiranya and Mantha what had happened. Hiranya said, “Do not worry. My teeth are sharp. If we act quickly, we can save him.”
# Mantha added calmly, “But we must be clever. The hunter may return at any moment.”
# Megha flew back to Chitranga and whispered, “Do not panic. Pretend you are dead. Lie still.”
# Then Megha flew high and began circling the sky, cawing loudly. The noise caught the attention of the hunter, who soon arrived to check his net. When he saw the deer lying motionless, he thought, “The animal is already dead. I will return later to collect it.”
# As soon as the hunter left, Hiranya rushed in and began gnawing at the ropes of the net. His teeth worked swiftly, and soon the net was cut open.
# But before Chitranga could escape, Mantha, who had come slowly behind, was spotted by the hunter returning unexpectedly. The hunter caught the tortoise and tied him up.
# Chitranga was filled with guilt and fear. “This happened because of me,” he cried.
# Megha said firmly, “Now it is our turn to save Mantha. Listen carefully.”
# They formed a plan. Chitranga ran toward the path, pretending to limp badly. Megha flew low, acting as if he were injured. Seeing this, the hunter thought, “If I follow them, I can catch even more animals.”
# The hunter dropped Mantha by the side of the path and ran after the deer and the crow. As soon as he was far away, Hiranya hurried to Mantha and gnawed through the ropes binding him.
# Once free, Mantha slowly crawled into the bushes. Meanwhile, Chitranga and Megha escaped into the forest. The hunter, realizing he had been tricked, returned angrily but found nothing.
# That evening, the four friends reunited at the lake. They were tired but grateful. Mantha spoke gently, “Today we have learned that intelligence, patience, speed, and unity together can overcome even great danger.”
# Hiranya added, “Each of us alone would have failed, but together we succeeded.”
# Chitranga bowed his head and said, “I will never forget this kindness. True friendship is life itself.”
# Megha looked at the setting sun and said, “As long as we trust one another and act wisely, no enemy can defeat us.”
# From that day on, the friends lived cautiously but happily, always helping one another in times of trouble.
# Moral: True friendship, guided by wisdom and cooperation, can overcome even the greatest dangers.

# %%
# print metadata
for doc in docs:
    print(doc.metadata)
# Out:
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '59aaf355513ff4ab453e2437753d8776'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '3ba11f4babeb3bb5de8aa39fbaa1fb27'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '922dbb6e66f75188c5884d9bea49d587'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '8a556b4a8705d6899da9db8f427d365a'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'e335fbc08ecbba640713153fdc090da8'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9580305586a97fd1e8c117aa37157448'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '057986f861ec6036f69c58f5dcfeb53a'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '71915c3564cad1cbc929be72ae6b3602'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'ba8ea4a78b48fb4ca7819128f25492e5'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '7a63d422adc0ac68adb4818dcdb096e8'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'e577163663f3a661fd8ca6718fbb4e63'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9fc83788c21b238c250c6a14170b3e43'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'd3942b904350db1f91c3e77c29e02c16'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f540e6b884a3d982f39df47f3966cd04'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '48aead6381bd846eabf54003d4edafdf'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '63ce12c865e9547bc4eb4a0194629fd4'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'afe7ada7b42b30f4502db42f63147195'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f62ad51320dd2fcaac7876c5b012f1cc'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f0a564f10e778a49c926d1a8ede40e0e'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a63d44df3ed3d5560849ee1acca75b9b'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'c026c58b6f31c4aa61870eb90dd14a59'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9622bfa80c35b1e37265ba3a1a8ee2d9'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'c56109fc54824755abcfb81bc7e7ad57'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '8693e701193fb4258423e948ce1f3383'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a6f587f7d1109097f97b907db17ea0cd'}

# %%
# Lets load the pdf document
from langchain_community.document_loaders import PyPDFLoader

pdf_loader = PyPDFLoader("../data/panchatantra.pdf")
pdf_docs = pdf_loader.load()

# %%
for pdf_doc in pdf_docs:
    print(pdf_doc)
# Out:
# page_content='Long ago, in a vast and fertile kingdom
# bordered by rivers and forests, there
# stood a small village surrounded by mango
# trees and open fields. Near this village
# lived three close friends: a crow named
# Megha, a mouse named Hiranya, and a
# tortoise named Mantha. Though they were
# very different in size and nature, they
# trusted one another deeply and lived in
# harmony.
# Megha, the crow, was sharp-eyed and
# quick-thinking. He spent his days flying
# across the land, observing the ways of
# humans and animals alike. Hiranya, the
# mouse, was small but extremely
# intelligent, with strong teeth and a
# quicker mind. Mantha, the tortoise, was
# slow in movement but wise and patient,
# known for thinking carefully before
# speaking or acting.
# Every evening, the three friends met near
# a quiet lake at the edge of the forest.
# They shared food, stories, and advice.' metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}
# page_content='Each respected the strengths of the
# others, and their friendship grew
# stronger with time.
# One summer, a terrible drought struck the
# land. The lake began to dry, crops
# failed, and food became scarce. Animals
# wandered far from their homes in search
# of water. The friends realized that
# difficult times were approaching.
# One evening, Megha flew in from afar
# looking worried. He said, “Friends, I
# have seen hunters setting traps near the
# forest. They are taking advantage of the
# drought. We must be careful.”
# Mantha nodded slowly. “Hard times test
# true friendship. We must remain united.”
# A few days later, a graceful deer named
# Chitranga came to the lake to drink
# water. He looked exhausted and
# frightened. Megha spoke kindly to him and
# invited him to join their group. Soon,' metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}
# page_content='Chitranga became part of their circle,
# and the four lived together peacefully.
# One morning, while Chitranga went to
# graze, he unknowingly stepped into a
# hunter’s net hidden beneath dry grass. He
# struggled and cried out in fear. Hearing
# his cries, Megha flew up into the sky and
# quickly saw the danger.
# Megha rushed back to the lake and told
# Hiranya and Mantha what had happened.
# Hiranya said, “Do not worry. My teeth are
# sharp. If we act quickly, we can save
# him.”
# Mantha added calmly, “But we must be
# clever. The hunter may return at any
# moment.”
# Megha flew back to Chitranga and
# whispered, “Do not panic. Pretend you are
# dead. Lie still.”
# Then Megha flew high and began circling' metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}
# page_content='the sky, cawing loudly. The noise caught
# the attention of the hunter, who soon
# arrived to check his net. When he saw the
# deer lying motionless, he thought, “The
# animal is already dead. I will return
# later to collect it.”
# As soon as the hunter left, Hiranya
# rushed in and began gnawing at the ropes
# of the net. His teeth worked swiftly, and
# soon the net was cut open.
# But before Chitranga could escape,
# Mantha, who had come slowly behind, was
# spotted by the hunter returning
# unexpectedly. The hunter caught the
# tortoise and tied him up.
# Chitranga was filled with guilt and fear.
# “This happened because of me,” he cried.
# Megha said firmly, “Now it is our turn to
# save Mantha. Listen carefully.”
# They formed a plan. Chitranga ran toward' metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}
# page_content='the path, pretending to limp badly. Megha
# flew low, acting as if he were injured.
# Seeing this, the hunter thought, “If I
# follow them, I can catch even more
# animals.”
# The hunter dropped Mantha by the side of
# the path and ran after the deer and the
# crow. As soon as he was far away, Hiranya
# hurried to Mantha and gnawed through the
# ropes binding him.
# Once free, Mantha slowly crawled into the
# bushes. Meanwhile, Chitranga and Megha
# escaped into the forest. The hunter,
# realizing he had been tricked, returned
# angrily but found nothing.
# That evening, the four friends reunited
# at the lake. They were tired but
# grateful. Mantha spoke gently, “Today we
# have learned that intelligence, patience,
# speed, and unity together can overcome
# even great danger.”' metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}
# page_content='Hiranya added, “Each of us alone would
# have failed, but together we succeeded.”
# Chitranga bowed his head and said, “I
# will never forget this kindness. True
# friendship is life itself.”
# Megha looked at the setting sun and said,
# “As long as we trust one another and act
# wisely, no enemy can defeat us.”
# From that day on, the friends lived
# cautiously but happily, always helping
# one another in times of trouble.
# Moral: True friendship, guided by wisdom
# and cooperation, can overcome even the
# greatest dangers.' metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}

# %%
for pdf_doc in pdf_docs:
    print(pdf_doc.metadata)
# Out:
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-01-20T08:31:31+05:30', 'author': '', 'moddate': '2026-01-20T08:31:31+05:30', 'title': '*Long ago, in a vast and fertile kin - Notepad', 'source': '../data/panchatantra.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_unstructured import UnstructuredLoader

directory_loader = DirectoryLoader(path="../data/books", glob="**/*.txt",loader_cls=UnstructuredLoader)
docs = directory_loader.load()

for doc in docs:
    print(doc.metadata)
# Out:
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'one.txt', 'filetype': 'text/plain', 'category': 'Title', 'element_id': '0882039d0f3715a9b93ee1b47ca506a2'}
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'one.txt', 'filetype': 'text/plain', 'parent_id': '0882039d0f3715a9b93ee1b47ca506a2', 'category': 'NarrativeText', 'element_id': '57c4ffff2664ba412309f5e74bf71e5a'}
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'one.txt', 'filetype': 'text/plain', 'parent_id': '0882039d0f3715a9b93ee1b47ca506a2', 'category': 'NarrativeText', 'element_id': 'a3fd3687e394d1381a344d6abbea4ba7'}
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'one.txt', 'filetype': 'text/plain', 'parent_id': '0882039d0f3715a9b93ee1b47ca506a2', 'category': 'NarrativeText', 'element_id': '59c6c12b613240b5d8ad231b686d1d02'}
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'one.txt', 'filetype': 'text/plain', 'parent_id': '0882039d0f3715a9b93ee1b47ca506a2', 'category': 'NarrativeText', 'element_id': '547db4c92d23214ccda99084c97e3e08'}
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'one.txt', 'filetype': 'text/plain', 'parent_id': '0882039d0f3715a9b93ee1b47ca506a2', 'category': 'NarrativeText', 'element_id': '54b34a3ff61986f7a2efc020725c32e1'}
# {'source': '..\\data\\books\\one.txt', 'last_modified': '2026-01-20T08:34:59', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 
 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'two.txt', 'filetype': 'text/plain', 'parent_id': 'e9f50fcf609d073eb0be090a45a2a7ab', 'category': 'NarrativeText', 'element_id': '5b390a539ae2990757a6a04a28e29d29'}
# {'source': '..\\data\\books\\two.txt', 'last_modified': '2026-01-20T08:35:10', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'two.txt', 'filetype': 'text/plain', 'parent_id': 'e9f50fcf609d073eb0be090a45a2a7ab', 'category': 'NarrativeText', 'element_id': '228b9dd20ba8bbf9c58fa9fc0f717c7b'}
# {'source': '..\\data\\books\\two.txt', 'last_modified': '2026-01-20T08:35:10', 'languages': ['eng'], 'file_directory': '..\\data\\books', 'filename': 'two.txt', 'filetype': 'text/plain', 'parent_id': 'e9f50fcf609d073eb0be090a45a2a7ab', 'category': 'NarrativeText', 'element_id': 'ecb1ff8f22fe73dc7b03ccc16a371b2e'}

# %%
from langchain_community.document_loaders import WebBaseLoader

web_loader = WebBaseLoader(web_path="https://www.york.ac.uk/teaching/cws/wws/webpage1.html")
web_docs = web_loader.load()
# Out:
# WARNING: USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
for web_doc in web_docs:
    print(web_doc)
# Out:
# page_content='
#
# webpage1
#
#
#
#
#
# STARTING . . .
# There are lots of ways to create web pages using already coded programmes. These lessons will teach you how to use the underlying HyperText Markup Language -  HTML.
#
# HTML isn't computer code, but is a language that uses US English to enable texts (words, images, sounds) to be inserted and formatting such as colo(u)r and centre/ering to be written in. The process is fairly simple; the main difficulties often lie in small mistakes - if you slip up while word processing your reader may pick up your typos, but the page will still be legible. However, if your HTML is inaccurate the page may not appear - writing web pages is, at the least, very good practice for proof reading!
# Learning HTML will enable you to:
#
# create your own simple pages
# read and appreciate pages created by others
# develop an understanding of the creative and literary implications of web-texts
# have the confidence to branch out into more complex web design
#
# A HTML web page is made up of tags. Tags are placed in brackets like this < tag > . A tag tells the browser how to display information. Most tags need to be opened < tag > and closed < /tag >.
#
#  To make a simple web page you need to know only four tags:
#
# < HTML > tells the browser your page is written in HTML format
# < HEAD > this is a kind of preface of vital information that doesn't appear on the screen.
# < TITLE >Write the title of the web page here - this is the information that viewers see on the upper bar of their screen. (I've given this page the title 'webpage1').
# < BODY >This is where you put the content of your page, the words and pictures that people read on the screen.
#
# All these tags need to be closed.
#
# EXERCISE
# Write a simple web page.
#  Copy out exactly the HTML below, using a WP program such as Notepad.
# Information in italics indicates where you can insert your own text, other information is HTML and needs to be exact. However, make sure there are no spaces between the tag brackets and the text inside.
# (Find Notepad by going to the START menu\ PROGRAMS\ ACCESSORIES\ NOTEPAD).
#
# < HTML >
# < HEAD >
# < TITLE > title of page< /TITLE >
# < /HEAD >
# < BODY>
#  write what you like here: 'my first web page', or a piece about what you are reading, or a few thoughts on the course, or copy out a few words from a book or cornflake packet.  Just type in your words using no extras such as bold, or italics, as these have special HTML tags, although you may use upper and lower case letters and single spaces.
#
# < /BODY >
# < /HTML >
# Save the file as 'first.html' (ie. call the file anything at all) It's useful if you start a folder - just as you would for word-processing - and call it something like WEBPAGES, and put your first.html file in the folder.
#
# NOW - open your browser.
# On Netscape the process is:
# Top menu; FILE\ OPEN PAGE\ CHOOSE FILE
# Click on your WEBPAGES folder\ FIRST file
# Click 'open' and your page should appear.
# On Internet Explorer:
# Top menu; FILE\ OPEN\ BROWSE
# Click on your WEBPAGES folder\ FIRST file
# Click 'open' and your page should appear.
# If the page doesn't open, go back over your notepad typing and make sure that all the HTML tags are correct. Check there are no spaces between tags and internal text; check that all tags are closed; check that you haven't written < HTLM > or < BDDY >.  Your page will work eventually.
#
# Make another page. Call it somethingdifferent.html and place it in the same WEBPAGES folder as detailed above.
# start formatting in lesson two
# back to wws index
#
#
#
#
#
#
#
# ' metadata={'source': 'https://www.york.ac.uk/teaching/cws/wws/webpage1.html', 'title': 'webpage1'}

# %%
from langchain_unstructured import UnstructuredLoader

txt_loader = UnstructuredLoader(file_path="../data/panchatantra.txt")

docs = txt_loader.load()
# Out:
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
print(f"docs {len(docs)}")
# Out:
# docs 25

# %%
for doc in docs:
    print(doc.page_content)
# Out:
# Long ago, in a vast and fertile kingdom bordered by rivers and forests, there stood a small village surrounded by mango trees and open fields. Near this village lived three close friends: a crow named Megha, a mouse named Hiranya, and a tortoise named Mantha. Though they were very different in size and nature, they trusted one another deeply and lived in harmony.
# Megha, the crow, was sharp-eyed and quick-thinking. He spent his days flying across the land, observing the ways of humans and animals alike. Hiranya, the mouse, was small but extremely intelligent, with strong teeth and a quicker mind. Mantha, the tortoise, was slow in movement but wise and patient, known for thinking carefully before speaking or acting.
# Every evening, the three friends met near a quiet lake at the edge of the forest. They shared food, stories, and advice. Each respected the strengths of the others, and their friendship grew stronger with time.
# One summer, a terrible drought struck the land. The lake began to dry, crops failed, and food became scarce. Animals wandered far from their homes in search of water. The friends realized that difficult times were approaching.
# One evening, Megha flew in from afar looking worried. He said, “Friends, I have seen hunters setting traps near the forest. They are taking advantage of the drought. We must be careful.”
# Mantha nodded slowly. “Hard times test true friendship. We must remain united.”
# A few days later, a graceful deer named Chitranga came to the lake to drink water. He looked exhausted and frightened. Megha spoke kindly to him and invited him to join their group. Soon, Chitranga became part of their circle, and the four lived together peacefully.
# One morning, while Chitranga went to graze, he unknowingly stepped into a hunter’s net hidden beneath dry grass. He struggled and cried out in fear. Hearing his cries, Megha flew up into the sky and quickly saw the danger.
# Megha rushed back to the lake and told Hiranya and Mantha what had happened. Hiranya said, “Do not worry. My teeth are sharp. If we act quickly, we can save him.”
# Mantha added calmly, “But we must be clever. The hunter may return at any moment.”
# Megha flew back to Chitranga and whispered, “Do not panic. Pretend you are dead. Lie still.”
# Then Megha flew high and began circling the sky, cawing loudly. The noise caught the attention of the hunter, who soon arrived to check his net. When he saw the deer lying motionless, he thought, “The animal is already dead. I will return later to collect it.”
# As soon as the hunter left, Hiranya rushed in and began gnawing at the ropes of the net. His teeth worked swiftly, and soon the net was cut open.
# But before Chitranga could escape, Mantha, who had come slowly behind, was spotted by the hunter returning unexpectedly. The hunter caught the tortoise and tied him up.
# Chitranga was filled with guilt and fear. “This happened because of me,” he cried.
# Megha said firmly, “Now it is our turn to save Mantha. Listen carefully.”
# They formed a plan. Chitranga ran toward the path, pretending to limp badly. Megha flew low, acting as if he were injured. Seeing this, the hunter thought, “If I follow them, I can catch even more animals.”
# The hunter dropped Mantha by the side of the path and ran after the deer and the crow. As soon as he was far away, Hiranya hurried to Mantha and gnawed through the ropes binding him.
# Once free, Mantha slowly crawled into the bushes. Meanwhile, Chitranga and Megha escaped into the forest. The hunter, realizing he had been tricked, returned angrily but found nothing.
# That evening, the four friends reunited at the lake. They were tired but grateful. Mantha spoke gently, “Today we have learned that intelligence, patience, speed, and unity together can overcome even great danger.”
# Hiranya added, “Each of us alone would have failed, but together we succeeded.”
# Chitranga bowed his head and said, “I will never forget this kindness. True friendship is life itself.”
# Megha looked at the setting sun and said, “As long as we trust one another and act wisely, no enemy can defeat us.”
# From that day on, the friends lived cautiously but happily, always helping one another in times of trouble.
# Moral: True friendship, guided by wisdom and cooperation, can overcome even the greatest dangers.

# %%
for doc in docs:
    print(doc.metadata)
# Out:
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '59aaf355513ff4ab453e2437753d8776'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '3ba11f4babeb3bb5de8aa39fbaa1fb27'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '922dbb6e66f75188c5884d9bea49d587'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '8a556b4a8705d6899da9db8f427d365a'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'e335fbc08ecbba640713153fdc090da8'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9580305586a97fd1e8c117aa37157448'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '057986f861ec6036f69c58f5dcfeb53a'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '71915c3564cad1cbc929be72ae6b3602'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'ba8ea4a78b48fb4ca7819128f25492e5'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '7a63d422adc0ac68adb4818dcdb096e8'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'e577163663f3a661fd8ca6718fbb4e63'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9fc83788c21b238c250c6a14170b3e43'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'd3942b904350db1f91c3e77c29e02c16'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f540e6b884a3d982f39df47f3966cd04'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '48aead6381bd846eabf54003d4edafdf'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '63ce12c865e9547bc4eb4a0194629fd4'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'afe7ada7b42b30f4502db42f63147195'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f62ad51320dd2fcaac7876c5b012f1cc'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f0a564f10e778a49c926d1a8ede40e0e'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a63d44df3ed3d5560849ee1acca75b9b'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'c026c58b6f31c4aa61870eb90dd14a59'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9622bfa80c35b1e37265ba3a1a8ee2d9'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'c56109fc54824755abcfb81bc7e7ad57'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '8693e701193fb4258423e948ce1f3383'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a6f587f7d1109097f97b907db17ea0cd'}

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
chunks = splitter.split_documents(docs)

print(f"chunks {len(chunks)}")
# Out:
# chunks 61

# %%
# print chunk content
for chunk in chunks:
    print(chunk.page_content)
# Out:
# Long ago, in a vast and fertile kingdom bordered by rivers and forests, there stood a small village
# a small village surrounded by mango trees and open fields. Near this village lived three close
# lived three close friends: a crow named Megha, a mouse named Hiranya, and a tortoise named Mantha.
# named Mantha. Though they were very different in size and nature, they trusted one another deeply
# one another deeply and lived in harmony.
# Megha, the crow, was sharp-eyed and quick-thinking. He spent his days flying across the land,
# across the land, observing the ways of humans and animals alike. Hiranya, the mouse, was small but
# was small but extremely intelligent, with strong teeth and a quicker mind. Mantha, the tortoise,
# the tortoise, was slow in movement but wise and patient, known for thinking carefully before
# carefully before speaking or acting.
# Every evening, the three friends met near a quiet lake at the edge of the forest. They shared food,
# They shared food, stories, and advice. Each respected the strengths of the others, and their
# others, and their friendship grew stronger with time.
# One summer, a terrible drought struck the land. The lake began to dry, crops failed, and food became
# and food became scarce. Animals wandered far from their homes in search of water. The friends
# water. The friends realized that difficult times were approaching.
# One evening, Megha flew in from afar looking worried. He said, “Friends, I have seen hunters setting
# hunters setting traps near the forest. They are taking advantage of the drought. We must be
# drought. We must be careful.”
# Mantha nodded slowly. “Hard times test true friendship. We must remain united.”
# A few days later, a graceful deer named Chitranga came to the lake to drink water. He looked
# water. He looked exhausted and frightened. Megha spoke kindly to him and invited him to join their
# him to join their group. Soon, Chitranga became part of their circle, and the four lived together
# four lived together peacefully.
# One morning, while Chitranga went to graze, he unknowingly stepped into a hunter’s net hidden
# hunter’s net hidden beneath dry grass. He struggled and cried out in fear. Hearing his cries, Megha
# his cries, Megha flew up into the sky and quickly saw the danger.
# Megha rushed back to the lake and told Hiranya and Mantha what had happened. Hiranya said, “Do not
# said, “Do not worry. My teeth are sharp. If we act quickly, we can save him.”
# Mantha added calmly, “But we must be clever. The hunter may return at any moment.”
# Megha flew back to Chitranga and whispered, “Do not panic. Pretend you are dead. Lie still.”
# Then Megha flew high and began circling the sky, cawing loudly. The noise caught the attention of
# the attention of the hunter, who soon arrived to check his net. When he saw the deer lying
# saw the deer lying motionless, he thought, “The animal is already dead. I will return later to
# return later to collect it.”
# As soon as the hunter left, Hiranya rushed in and began gnawing at the ropes of the net. His teeth
# the net. His teeth worked swiftly, and soon the net was cut open.
# But before Chitranga could escape, Mantha, who had come slowly behind, was spotted by the hunter
# by the hunter returning unexpectedly. The hunter caught the tortoise and tied him up.
# Chitranga was filled with guilt and fear. “This happened because of me,” he cried.
# Megha said firmly, “Now it is our turn to save Mantha. Listen carefully.”
# They formed a plan. Chitranga ran toward the path, pretending to limp badly. Megha flew low, acting
# flew low, acting as if he were injured. Seeing this, the hunter thought, “If I follow them, I can
# follow them, I can catch even more animals.”
# The hunter dropped Mantha by the side of the path and ran after the deer and the crow. As soon as he
# crow. As soon as he was far away, Hiranya hurried to Mantha and gnawed through the ropes binding
# the ropes binding him.
# Once free, Mantha slowly crawled into the bushes. Meanwhile, Chitranga and Megha escaped into the
# escaped into the forest. The hunter, realizing he had been tricked, returned angrily but found
# angrily but found nothing.
# That evening, the four friends reunited at the lake. They were tired but grateful. Mantha spoke
# Mantha spoke gently, “Today we have learned that intelligence, patience, speed, and unity together
# and unity together can overcome even great danger.”
# Hiranya added, “Each of us alone would have failed, but together we succeeded.”
# Chitranga bowed his head and said, “I will never forget this kindness. True friendship is life
# friendship is life itself.”
# Megha looked at the setting sun and said, “As long as we trust one another and act wisely, no enemy
# wisely, no enemy can defeat us.”
# From that day on, the friends lived cautiously but happily, always helping one another in times of
# another in times of trouble.
# Moral: True friendship, guided by wisdom and cooperation, can overcome even the greatest dangers.

# %%
for chunk in chunks:
    print(chunk.metadata)
# Out:
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id':

# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16504\2097165590.py:3: DeprecationWarning: Use [`GoogleGenerativeAIEmbeddings`][langchain_google_genai.GoogleGenerativeAIEmbeddings] instead.
#   embedding = VertexAIEmbeddings(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16504\2097165590.py:3: LangChainDeprecationWarning: The class `VertexAIEmbeddings` was deprecated in LangChain 3.2.0 and will be removed in 4.0.0. An updated version of the class exists in the `langchain-google-genai package and should be used instead. To use it run `pip install -U `langchain-google-genai` and import as `from `langchain_google_genai import GoogleGenerativeAIEmbeddings``.
#   embedding = VertexAIEmbeddings(

# %%
embedding
# Out:
# VertexAIEmbeddings(client=<google.genai.client.Client object at 0x0000022AA21FEF90>, project=None, location='us-central1', model_name='text-embedding-005', credentials=None, max_retries=6, dimensions=None)

# %%
vectors = embedding.embed_documents(["How are you?", "What are you doing?"])
# Out:
# INFO: HTTP Request: POST https://us-central1-aiplatform.googleapis.com/v1beta1/projects/massive-seer-457104-j1/locations/us-central1/publishers/google/models/text-embedding-005:predict "HTTP/1.1 200 OK"

# %%
for vector in vectors:
    print(vector)
# Out:
# [-0.0045494274236261845, -0.017216427251696587, -0.0324680395424366, -0.022340374067425728, -0.020613254979252815, 0.03246522322297096, -0.009709269739687443, 0.005146731156855822, -0.0446588508784771, 0.01614672690629959, -0.043128278106451035, -0.0643366202712059, 0.01573803462088108, -0.05111204832792282, -0.029942944645881653, 0.046102479100227356, 0.017887718975543976, -0.091363824903965, 0.012065109796822071, 0.06209949404001236, 0.02921321988105774, -0.06699862331151962, -0.01671951450407505, -0.030738819390535355, 0.039306726306676865, -0.006393258925527334, -0.02222333289682865, -0.03143469989299774, -0.041224051266908646, 0.03726210817694664, 0.03374296799302101, -0.03309953212738037, 0.022117553278803825, 0.016167741268873215, 0.005234218668192625, 0.018517950549721718, 0.08943136036396027, 0.004995774477720261, 0.028497613966464996, -0.02052643895149231, -0.012263184413313866, -0.010356671176850796, -0.025333017110824585, -0.018368110060691833, 0.01594443805515766, 0.04973004758358002, -0.037703774869441986, -0.028729693964123726, 0.014903409406542778, -0.06665603816509247, 0.004389982204884291, 0.041361063718795776, -0.018939074128866196, -0.01865205354988575, 0.0002670272078830749, 0.059603508561849594, 0.005760966334491968, 0.04975461959838867, -0.02340009994804859, 0.0202530138194561, -0.011167291551828384, -0.038649410009384155, -0.021112514659762383, 0.002349898684769869, -0.07938014715909958, 0.02535376511514187, 0.03398946672677994, 0.03152122721076012, 0.010465274564921856, -0.011169121600687504, -0.020429668948054314, -0.042678818106651306, 0.009344234131276608, 0.003605616744607687, -0.036431100219488144, -0.012911803089082241, 0.0035847860854119062, 0.08626348525285721, -0.03952522203326225, -0.011391929350793362, -0.029376937076449394, 0.00631766626611352, -0.008932366035878658, -0.00024927768390625715, 0.009609434753656387, -0.02583775669336319, -0.03359163552522659, -0.07045553624629974, -0.063639335334301, -0.07633661478757858, -0.022091098129749298, 0.008586185984313488, -0.02038038708269596, 0.022929318249225616, 0
#  -0.06611913442611694,
#  0.030348526313900948,
#  -0.0829276517033577,
#  0.030990945175290108,
#  -0.060410864651203156,
#  -0.12980856001377106,
#  0.007030524779111147,
#  0.02868310920894146,
#  -0.01895563118159771,
#  0.04325215891003609,
#  0.007604760583490133,
#  0.013086160644888878,
#  -0.0124130267649889,
#  -0.02836812101304531,
#  0.02179831825196743,
#  -0.025946656242012978,
#  0.038182903081178665,
#  -0.005378653295338154,
#  -0.011991639621555805,
#  -0.050916824489831924,
#  -0.02149534597992897,
#  -0.07571791857481003,
#  0.009815321303904057,
#  0.008269507437944412,
#  0.0037089192774146795,
#  -0.04845194146037102,
#  0.027035774663090706,
#  0.04059195891022682,
#  0.011644492857158184,
#  0.07366469502449036,
#  0.05267984792590141,
#  -0.027785753831267357,
#  -0.022616513073444366,
#  0.014787165448069572,
#  -0.02006003074347973,
#  -0.05441228300333023,
#  -0.01610283926129341]

# %%
from langchain_community.vectorstores import FAISS
# pass the chunks and embedding
vector_store = FAISS.from_documents(
    chunks,
    embedding=embedding
)
# Out:
# INFO: HTTP Request: POST https://us-central1-aiplatform.googleapis.com/v1beta1/projects/massive-seer-457104-j1/locations/us-central1/publishers/google/models/text-embedding-005:predict "HTTP/1.1 200 OK"
# INFO: Loading faiss with AVX2 support.
# INFO: Successfully loaded faiss with AVX2 support.

# %%
retriever = vector_store.as_retriever()

# %%
results = retriever.invoke("where did Megha flew back ?")
# Out:
# INFO: HTTP Request: POST https://us-central1-aiplatform.googleapis.com/v1beta1/projects/massive-seer-457104-j1/locations/us-central1/publishers/google/models/text-embedding-005:predict "HTTP/1.1 200 OK"

# %%
for result in results:
    print(result.page_content)
# Out:
# Megha flew back to Chitranga and whispered, “Do not panic. Pretend you are dead. Lie still.”
# Then Megha flew high and began circling the sky, cawing loudly. The noise caught the attention of
# his cries, Megha flew up into the sky and quickly saw the danger.
# Megha rushed back to the lake and told Hiranya and Mantha what had happened. Hiranya said, “Do not

# %%
results = retriever.invoke("How did Mantha nodd ?")
for result in results:
    print(result.page_content)
# Out:
# INFO: HTTP Request: POST https://us-central1-aiplatform.googleapis.com/v1beta1/projects/massive-seer-457104-j1/locations/us-central1/publishers/google/models/text-embedding-005:predict "HTTP/1.1 200 OK"
# Mantha added calmly, “But we must be clever. The hunter may return at any moment.”
# The hunter dropped Mantha by the side of the path and ran after the deer and the crow. As soon as he
# Mantha nodded slowly. “Hard times test true friendship. We must remain united.”
# That evening, the four friends reunited at the lake. They were tired but grateful. Mantha spoke

# %%
for result in results:
    print(result.metadata)
# Out:
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '7a63d422adc0ac68adb4818dcdb096e8'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'f62ad51320dd2fcaac7876c5b012f1cc'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': '9580305586a97fd1e8c117aa37157448'}
# {'source': '../data/panchatantra.txt', 'last_modified': '2026-01-20T08:16:20', 'languages': ['eng'], 'file_directory': '../data', 'filename': 'panchatantra.txt', 'filetype': 'text/plain', 'category': 'NarrativeText', 'element_id': 'a63d44df3ed3d5560849ee1acca75b9b'}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
