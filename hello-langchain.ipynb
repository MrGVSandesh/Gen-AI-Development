# %%
from langchain.chat_models import init_chat_model

# %% [markdown]
# ## install necessary package
#
# * vertex `langchain-google-vertexai`

# %%
gemini_llm = init_chat_model("gemini-2.5-flash-lite", model_provider="google_vertexai")

# %%
response = gemini_llm.invoke("What is capital of france?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The capital of France is **Paris**.

# %%
openai_llm = init_chat_model("gpt-3.5-turbo", model_provider="openai")

# %%
response = openai_llm.invoke("What is capital of france?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The capital of France is Paris.

# %%
llama3_llm = init_chat_model("llama3.1:8b", model_provider="ollama")

# %%
response = llama3_llm.invoke("What is capital of france?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The capital of France is Paris.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

model = os.getenv("MODEL")
model_provider = os.getenv("MODEL_PROVIDER")

llm = init_chat_model(model, model_provider=model_provider)
response = llm.invoke("What is capital of france?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# The capital of France is **Paris**.

# %%
import os
load_dotenv()
model = os.getenv("MODEL")
model_provider = os.getenv("MODEL_PROVIDER")

llm = init_chat_model(model, model_provider=model_provider)
response = llm.invoke("Summarize about Christopher Nolan movies in 100 words")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Christopher Nolan crafts mind-bending cinematic experiences that often play with time, perception, and morality. His films, like *Inception*, *The Dark Knight* trilogy, and *Interstellar*, are known for their intricate plots, stunning visuals, and complex narratives that reward repeat viewings. Nolan frequently explores themes of identity, memory, and the human condition through ambitious storytelling, often employing practical effects and non-linear structures. He's a master of the blockbuster with intellectual depth, captivating audiences with both spectacle and profound questions.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# ...
