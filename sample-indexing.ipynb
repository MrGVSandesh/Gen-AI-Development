# %%
# indexing
# 1. loader
from langchain_unstructured import UnstructuredLoader
# 2. splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
# 3. embeddings
from langchain_google_vertexai.embeddings import VertexAIEmbeddings
# 4. vectorstore
from langchain_community.vectorstores import FAISS

# %%
document_loader = UnstructuredLoader("../data/policies.txt")

# %%
documents = document_loader.load()
# Out:
# WARNING: libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    separators=["\n\n", "\n", " ", ""])

# %%
chunks = splitter.split_documents(documents)

# %%
# embedding

embedding = VertexAIEmbeddings(model_name="text-embedding-005")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25628\200160130.py:3: DeprecationWarning: Use [`GoogleGenerativeAIEmbeddings`][langchain_google_genai.GoogleGenerativeAIEmbeddings] instead.
#   embedding = VertexAIEmbeddings(model_name="text-embedding-005")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25628\200160130.py:3: LangChainDeprecationWarning: The class `VertexAIEmbeddings` was deprecated in LangChain 3.2.0 and will be removed in 4.0.0. An updated version of the class exists in the `langchain-google-genai package and should be used instead. To use it run `pip install -U `langchain-google-genai` and import as `from `langchain_google_genai import GoogleGenerativeAIEmbeddings``.
#   embedding = VertexAIEmbeddings(model_name="text-embedding-005")

# %%
vector_store = FAISS.from_documents(chunks, embedding)
# Out:
# INFO: HTTP Request: POST https://us-central1-aiplatform.googleapis.com/v1beta1/projects/massive-seer-457104-j1/locations/us-central1/publishers/google/models/text-embedding-005:predict "HTTP/1.1 200 OK"
# INFO: Loading faiss with AVX2 support.
# INFO: Successfully loaded faiss with AVX2 support.

# %%
retriever = vector_store.as_retriever()

# %%
results = retriever.invoke("What are working hours")
# Out:
# INFO: HTTP Request: POST https://us-central1-aiplatform.googleapis.com/v1beta1/projects/massive-seer-457104-j1/locations/us-central1/publishers/google/models/text-embedding-005:predict "HTTP/1.1 200 OK"

# %%
for result in results:
    print(result.page_content)
# Out:
# WORKING HOURS Standard working hours will be defined by the organization and may vary by role or
# working hours and maintain punctuality. Any deviations must be approved by the reporting manager.
# may vary by role or department. Employees are expected to adhere to assigned working hours and
# holidays will be communicated separately. Leave should be planned in advance and approved by the
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
